# %%
import matplotlib.pyplot as plt
import scipy.io as spio 
import pandas as pd
import numpy as np
import os
import seaborn as sns
from my_tools import *
from ranked_structural_connectivity import *
import pickle
from IPython.display import Image
import matplotlib.lines as mlines
from scipy import spatial
from matplotlib import rcParams
rcParams.update({'font.size': 17})
import warnings
warnings.filterwarnings('ignore')

# %%
def unpickle(where_pkl):
    with open(where_pkl, 'rb') as f:
        return pickle.load(f)
    
class Patient:
    def __init__(self, plot_path,assessment_path,baseline_file,files_to_remove,vta_path):
        self.plot_path = plot_path
        self.assessment_path = assessment_path
        self.baseline_file = baseline_file
        self.files_to_remove = files_to_remove
        self.vta_path = vta_path
        
    def pickle(self, where_pkl):
        pickleFile = open(where_pkl, 'wb')
        pickle.dump(self, pickleFile)
        pickleFile.close()

# %%
# SAVIOR https://stackoverflow.com/questions/7008608/scipy-io-loadmat-nested-structures-i-e-dictionaries
def manual_loadmat(filename):
    '''
    this function should be called instead of direct spio.loadmat
    as it cures the problem of not properly recovering python dictionaries
    from mat files. It calls the function check keys to cure all entries
    which are still mat-objects
    '''
    data = spio.loadmat(filename, struct_as_record=False, squeeze_me=True)
    return _check_keys(data)

def _check_keys(dict):
    '''
    checks if entries in dictionary are mat-objects. If yes
    todict is called to change them to nested dictionaries
    '''
    for key in dict:
        if isinstance(dict[key], spio.matlab.mio5_params.mat_struct):
            dict[key] = _todict(dict[key])
    return dict        

def _todict(matobj):
    '''
    A recursive function which constructs from matobjects nested dictionaries
    '''
    dict = {}
    for strg in matobj._fieldnames:
        elem = matobj.__dict__[strg]
        if isinstance(elem, spio.matlab.mio5_params.mat_struct):
            dict[strg] = _todict(elem)
        else:
            dict[strg] = elem
    return dict

def improvement_df(mat_path):
    raw_mat = manual_loadmat(mat_path)
    mat = {k : el for k, el in raw_mat.items() if k.startswith('session')}
    improvement_df = pd.concat({k: pd.DataFrame.from_dict(v,orient='index').T for k, v in mat.items()})
    improvement_df.index.names = ['date', 'useless']
    improvement_df = improvement_df.reset_index().drop('useless',axis= 1)
    improvement_df['date'] = improvement_df['date'].apply(lambda x : x.split('session_')[1])
    return improvement_df

# %%
def find_date_extreme(patient_df, measure, mode):
    # patient_df has as many rows as there are session for the patient
    # 8 columns : date, MDD measures, result of improvement_df
    if mode == 'worst':
        index = patient_df[[measure]].idxmin().item()
    else:
        index = patient_df[[measure]].idxmax().item()
    date_extreme = patient_df.iloc[index][['date',measure]]['date']
    
    return date_extreme

# %%
def create_bilateral_df(patient, parcellation_path_Brodmann):
    
    sorted_code_list = np.load(patient.plot_path + '/sorted_code_list.npy')
    sorted_code_list = ['VTA_' + "{0:0=2d}".format(i) for i in sorted_code_list]
    loaded_stimulation_dicts = np.load(patient.assessment_path + '/corrected_stimulations.npy', allow_pickle='TRUE')

    dates = np.load(patient.plot_path + '/sorted_dates.npy')
    df = read_assessments(dates, patient.assessment_path, patient.baseline_file, patient.files_to_remove)
    all_measures = {'{}'.format(scale): df[df.measure == scale] for scale in list(df.measure.unique())}
    ranks = all_ranks(all_measures)
    mode = 'Brodmann' #maybe we will like the Dkt at some point
    labels = get_labels(parcellation_path_Brodmann, mode)
    # for side in ['left','right']:
    bilateral_df = bilateral_video(labels, patient.vta_path, dates, sorted_code_list)
    
    return bilateral_df

# %%
def create_pivoted(patient, parcellation_path_Brodmann, areas,out_path):
    bilateral_df = create_bilateral_df(patient, parcellation_path_Brodmann)
    
    ### get my colors! as in ranked connectivity
    bilateral_labels = list(bilateral_df.area.unique())
    bilateral_labels.append('All_other')
    bilateral_labels = every_other4(bilateral_labels)
    #bilateral_labels = change_order(bilateral_labels)
    cmap = plt.cm.tab20
    rcParams['axes.prop_cycle'] = cycler(color=cmap(np.linspace(0, 1, 40)))
    list_arrays = rcParams['axes.prop_cycle'].by_key()['color']
    list_arrays_alpha = [change_alpha(el) if i % 2 == 0 else el for i, el in enumerate(list_arrays)]
    my_colors = dict(zip(bilateral_labels, list_arrays_alpha))
    
    piv = visualize_connectivity(bilateral_df, 8, out_path, show=False)
    #piv['date'] = piv.apply(lambda x : pd.to_datetime(x.date,format = '%d.%m.%Y'),axis=1)
    return piv, my_colors

# %%
def line_df(id_pat, pivoted, global_patient, measure, mode):
    
    date_extreme = find_date_extreme(global_patient, measure, mode)
    value_extreme = global_patient[global_patient.date ==date_extreme][measure].item()
    print('for', id_pat, 'the ', mode, 'VTA for measure ', measure, 'is at the date', date_extreme, 'with % improvement', value_extreme)
    df = pivoted[pivoted.date == pd.to_datetime(date_extreme,format = '%d_%m_%Y')]
    df.index = [id_pat]
    df['%impro'] = value_extreme
    return df, {id_pat : date_extreme}

# %%
def intersubjects(measure, mode, id_piv_dict, id_global_dict):
    df_n_dates = [ line_df(patient_id, pivoted_table, id_global_dict[patient_id], measure, mode) for patient_id, pivoted_table in id_piv_dict.items()]
    frames = [el[0] for el in df_n_dates ]
    dates_extremes = {k : v for el in df_n_dates for k, v in el[1].items()}
    return pd.concat(frames, sort=False), dates_extremes

# %%
def plot_connectivity_comparison(dataframe, save_dir, measure, mode,colors):
    # dataframe has as many rows as there are sessions, the date column and one more column than numb (used in minimize )
    
    fig, ax = plt.subplots(figsize=(6, 8))

    dataframe['date'] = dataframe.apply(lambda x: pd.to_datetime(x.date, format='%d.%m.%Y'), axis=1)  # datetime
    dataframe = dataframe.sort_values(by='date')

    dataframe['date'] = dataframe.date.dt.strftime('%d-%m-%Y')
    dataframe = dataframe.sort_index()
    x = [name+'\n'+str(perc)+'%' for name, perc in zip(dataframe.index,dataframe['%impro'])]
#     x = dataframe.index
#     y = dataframe['%impro']
#     print('ppppppppppppppp', [name+'\n'+str(perc) for name, perc in zip(x,y)])
    to_use = dataframe.drop(['date','%impro'],axis=1).fillna(0)

    cmap = plt.cm.tab20
    rcParams['axes.prop_cycle'] = cycler(color=cmap(np.linspace(0, 1, len(to_use.columns))))
    mpp_colors = dict(zip(to_use.columns, rcParams['axes.prop_cycle'].by_key()['color']))

    indexes = np.argsort(to_use.values).T  # row by row get order, then transpose
    heights = np.sort(to_use.values).T  # sorts row by row, then transpose
    order = -1
    bottoms = heights[::order].cumsum(
        axis=0)  # reads heights from bottom row to first row, then second row is sum first + second ecc
    bottoms = np.insert(bottoms, 0, np.zeros(len(bottoms[0])), axis=0)  # adds a first row of zeros
    for btms, (idxs, vals) in enumerate(list(zip(indexes, heights))[::order]):
        mps = np.take(np.array(to_use.columns), idxs)  # get name of column at idxs
        ax.bar(x, height=vals, bottom=bottoms[btms], color=[colors[m] for m in mps])


    ax.set_ylim(bottom=0, top=102)
    #ax.xaxis.labelpad = 20
    plt.legend((np.take(np.array(to_use.columns), np.argsort(to_use.values)[0]))[::order], loc='center right',
               bbox_to_anchor=(1.50, 0.5), fancybox=True,
               shadow=True, title='Brodmann area')
    plt.xticks(rotation=45)
    plt.title('{mod} VAT for measure {mea} across subjects'.format(mod = mode.capitalize(), mea = measure))
    #plt.xlabel('Patient')
    plt.ylabel('% of strength connectivity')
    plt.savefig(os.path.join(save_dir, 'All_patients_struct_{}'.format(measure)), bbox_inches="tight")

    return

# %%
def date_to_VTA_code(date, patient):
    all_dates = np.load(patient.plot_path+'/sorted_dates.npy')
    all_codes =  np.load(patient.plot_path+'/sorted_code_list.npy')
    index_date = np.argwhere(all_dates == date.replace('_','.')).item()
    unique_VTA_code = all_codes[index_date]
    unique_VTA_code_string = 'VTA_' + "{0:0=2d}".format(unique_VTA_code)
    
    return unique_VTA_code_string #Image(filename=os.path.join(patient.vta_path, unique_VTA_code_string, 'Bimodal_connectivity_{}.png'.format(unique_VTA_code_string)))

# %%
#only structural
def only_structural(structural, VTA_name, destination_folder=False, sorting=False, scaling=False, custom_title = False):
    # define 4 color-blind friendly colors from https://gist.github.com/thriveth/8560036
    col1 = '#377eb8'
    col2 = '#ff7f00'
    col3 = '#4daf4a'
    col4 = '#a65628'

    if sorting:
        structural = structural.sort_values(by='sum_of_weight')

    fig, ax = plt.subplots(figsize=(18, 5))
    if custom_title:
        plt.title(custom_title, fontsize=18)
    else:
        plt.title('Functional connectivity for {}'.format(VTA_name), fontsize=18)

    # using the twinx() for creating another
    # axes object for secondary y-Axis
    ax2 = ax.twinx()

    # Functional
#     col = np.where(structural.average_value < 0, col1, col2)
    ax.scatter(structural.area, abs(structural.perc)*0, c='white')
#     if scaling:
#         max_functional = max(abs(bimodal.average_value)) + max(abs(bimodal.average_value)) * 0.1
#         ax.set_ylim([0, max_functional])
#     else:
    ax.set_ylim([0, 0.5])

    # giving labels to the axes
    ax.set_xlabel('Brodmann Area')
#     ax.set_ylabel('Mean functional connection of BA to VTA', color=col3, weight='bold')
    ax.set_xticklabels(structural.area, rotation=70)
    ax.tick_params(axis='y', colors=col3)
    # Structural
    if scaling:
        max_structural = max(structural.perc) + max(structural.perc) * 0.1
        ax2.set_ylim([0, max_structural])
    else:
        ax2.set_ylim([0, 100])

    ax2.bar(structural.area, structural.perc, label='Structural connectivity', color='b', alpha=0.2)
#     positive = mlines.Line2D([], [], color=col2, marker='.',
#                              markersize=15, label='Positive functional connectivity')
#     negative = mlines.Line2D([], [], color=col1, marker='.',
#                              markersize=15, label='Negative functional connectivity')

    ax2.set_ylabel('% weights VAT to BA', color=col4, weight='bold')
    ax2.tick_params(axis='y', colors=col4)

    # where some data has already been plotted to ax
    handles, labels = ax2.get_legend_handles_labels()

    # handles is a list, so append manual patch
#     handles.append(positive)
#     handles.append(negative)

    plt.legend(handles=handles, bbox_to_anchor=(1.25, 0.95), fancybox=True,
               shadow=True)
    # defining display layout

    if destination_folder:
        plt.savefig(os.path.join(destination_folder, 'Bimodal_connectivity_{}'.format(VTA_name)), bbox_inches='tight')
    else:
        plt.show()
    return

# %%
def bimodal_connectivity(bimodal, VTA_name, destination_folder=False, sorting=False, scaling=False, custom_title = False):
    # define 4 color-blind friendly colors from https://gist.github.com/thriveth/8560036
    col1 = '#377eb8'
    col2 = '#ff7f00'
    col3 = '#4daf4a'
    col4 = '#a65628'

    if sorting:
        bimodal = bimodal.sort_values(by='sum_of_weight')

    fig, ax = plt.subplots(figsize=(15, 5))
    if custom_title:
        plt.title(custom_title, fontsize=22)
    else:
        plt.title('Structural and functional connectivity for {}'.format(VTA_name), fontsize=18)

    # using the twinx() for creating another
    # axes object for secondary y-Axis
    ax2 = ax.twinx()

    # Functional
    col = np.where(bimodal.average_value < 0, col1, col2)
    ax.scatter(bimodal.label, abs(bimodal.average_value), c=col)
    if scaling:
        max_functional = max(abs(bimodal.average_value)) + max(abs(bimodal.average_value)) * 0.1
        ax.set_ylim([0, max_functional])
    else:
        ax.set_ylim([0, 0.5])

    # giving labels to the axes
    ax.set_xlabel('Brodmann Area')
    ax.xaxis.labelpad = 20
    ax.set_ylabel('Mean functional connection of BA to VAT', color=col3, weight='bold')
    ax.yaxis.labelpad = 20
    ax.set_xticklabels(bimodal.label, rotation=70)
    ax.tick_params(axis='y', colors=col3)
    # Structural
    if scaling:
        max_structural = max(bimodal.perc) + max(bimodal.perc) * 0.1
        ax2.set_ylim([0, max_structural])
    else:
        ax2.set_ylim([0, 100])

    ax2.bar(bimodal.label, bimodal.perc, label='Structural connectivity', color='b', alpha=0.2)
    positive = mlines.Line2D([], [], color=col2, marker='.',
                             markersize=15, label='Positive functional connectivity')
    negative = mlines.Line2D([], [], color=col1, marker='.',
                             markersize=15, label='Negative functional connectivity')

    ax2.set_ylabel('% weights VAT to BA', color=col4, weight='bold')
    ax2.yaxis.labelpad = 20
    ax2.tick_params(axis='y', colors=col4)

    # where some data has already been plotted to ax
    handles, labels = ax2.get_legend_handles_labels()

    # handles is a list, so append manual patch
    handles.append(positive)
    handles.append(negative)

    plt.legend(handles=handles, fancybox=True,
               shadow=True)
    # defining display layout

    if destination_folder:
        plt.savefig(os.path.join(destination_folder, 'Bimodal_connectivity_{}'.format(VTA_name)), bbox_inches='tight')
    else:
        plt.show()
    return

# %%
#refactoring bimodal_plot main
def bimodal_plot_main(patient, parcellation_path_Brodmann, VTA_code):
#     VTA_tracts_path = os.path.join(patient.patient_path, 'VTA_tracts')
    VTA_tracts = sorted([el for el in os.listdir(patient.vta_path) if el.startswith('VTA')])
    # loaded_stimulation_dicts = np.load(assessment_path + '/corrected_stimulations.npy', allow_pickle='TRUE')
    # get sequence of unique VTA codes in time
    sorted_code_list = np.load(patient.plot_path + '/sorted_code_list.npy')
    sorted_code_list = ['VTA_' + "{0:0=2d}".format(i) for i in sorted_code_list]
    # get sequence of dates
    dates = np.load(patient.plot_path + '/sorted_dates.npy')  # string with dd.mm.yyyy format
    labels = get_labels(parcellation_path_Brodmann, 'Brodmann')

    together = bilateral_video(labels, patient.vta_path, dates, sorted_code_list)

    date_to_code = dict(zip(dates, sorted_code_list))
    together['unique_VTA_code'] = together.apply(lambda x: date_to_code[x.date], axis=1)
    together.drop_duplicates(subset=['area', 'sum_of_weight', 'unique_VTA_code'], inplace=True)

    structural = together[together.unique_VTA_code == VTA_code.split('/')[-1]]
    
    if os.path.isfile(os.path.join(patient.vta_path,VTA_code, 'averaged_z_fingerprint.txt')):
        functional = pd.read_csv(os.path.join(patient.vta_path,VTA_code, 'averaged_z_fingerprint.txt'), sep=' ')
        bimodal = functional.merge(structural, left_on='label', right_on='area')
    else:
        bimodal = structural.copy()
        bimodal['label'] = bimodal.apply(lambda x : int(x.area.split('_')[0][2:]),axis = 1 )
        bimodal = bimodal.sort_values(by='label')

    total_weight_day = bimodal.groupby(['date']).sum().to_dict()['sum_of_weight']
    bimodal['perc'] = bimodal.apply(lambda x: (x.sum_of_weight / total_weight_day[x.date]) * 100, axis=1)
    #bimodal_connectivity(bimodal, patient.VTA_code.split('/')[-1], patient.save_path, sorting=True, scaling=False)
    return bimodal

# %%
def get_struct_profile(pat,brodman_path,day):
    day = day.replace('_','.')
    print(day)
    structural_df = create_bilateral_df(pat, brodman_path)
    connectivity_profile = list(structural_df[structural_df.date==day]['sum_of_weight'].values)
    
    return connectivity_profile

# %%
def compute_similarity(lst1,lst2):
    return 1-spatial.distance.cosine(lst1,lst2)

def plot_similarity(structural_profiles_dict):
    size = len(structural_profiles_dict)
    mat = np.zeros((size,size))
    for index in np.arange(size**2) :
        row, col = index//size, index % size
        lst1 = [profile for i, (patient, profile) in enumerate(structural_profiles_dict.items()) if i == row]
        lst2 = [profile for i, (patient, profile) in enumerate(structural_profiles_dict.items()) if i == col]
        mat[row,col] = compute_similarity(lst1,lst2)

    plt.subplots(figsize=(5,5))
    mask = np.tril(np.ones_like(mat))
    mask = np.where(mask==1,0,1)
    ax = sns.heatmap(mat, cmap="coolwarm",annot = True,vmin=0,vmax=1,mask=mask, xticklabels=list(structural_profiles_dict.keys()), yticklabels=list(structural_profiles_dict.keys()))
    plt.show()
                   
    return

# %%
def intersubjects_connectivity_summary(measure,modality, id_piv_dict, id_global_dict, id_patient_dict,parcellation_path_Brodmann,colors,destination_folder):
    both, dates_extr = intersubjects(measure,modality, id_piv_dict, id_global_dict)
    both = both.dropna(axis=1, how='all')

    patient_struct_profile = {patient_id: get_struct_profile(id_patient_dict[patient_id],parcellation_path_Brodmann,day) for patient_id, day in dates_extr.items()}
    plot_connectivity_comparison(both, destination_folder, measure,modality,colors)
    
    patient_func_profile = {}
    for patientID, date in dates_extr.items():
        vta_code = date_to_VTA_code(date, id_patient_dict[patientID])
        bimodal_df =  bimodal_plot_main(id_patient_dict[patientID], parcellation_path_Brodmann, vta_code)
       
        if 'average_value' in bimodal_df.columns:
            bimodal_connectivity(bimodal_df, vta_code, destination_folder, sorting=False, scaling=False, custom_title='{mode} bimodal connectivity for {patientid} on measure {measure}'.format(mode = modality.capitalize(), patientid=patientID, measure= measure))
            patient_func_profile[patientID] = list(bimodal_df.average_value.values)
        else:
           
            only_structural(bimodal_df, vta_code, destination_folder, sorting=False, scaling=False, custom_title='{mode} structural connectivity for {patientid} on measure {measure}'.format(mode = modality.capitalize(), patientid=patientID, measure= measure))
    
    plot_similarity(patient_struct_profile)
    plot_similarity(patient_func_profile)
    return

# %% [markdown]
# ## READ Patient instances

# %%
Pat1 = unpickle('/media/brainstimmaps/DATA/20xx_Projects/2025_DBSinDepression/03_Data/Patient1/Pat1.pkl')
Pat2 = unpickle('/media/brainstimmaps/DATA/20xx_Projects/2025_DBSinDepression/03_Data/Patient2/Pat2.pkl')
Pat3 = unpickle('/media/brainstimmaps/DATA/20xx_Projects/2025_DBSinDepression/03_Data/Patient3/Pat3.pkl')

# %% [markdown]
# ### Create improvement DF

# %%
pat1_df = improvement_df(Pat1.assessment_path+'/perc_impro.mat')
pat2_df = improvement_df(Pat2.assessment_path+'/perc_impro.mat')
pat3_df = improvement_df(Pat3.assessment_path+'/perc_impro.mat')

# %% [markdown]
# ### Create structural dataframe

# %%
piv1,my_colors = create_pivoted(Pat1,parcellation_path_Brodmann,8,'.')
piv2,my_colors = create_pivoted(Pat2,parcellation_path_Brodmann,8,'.')
piv3, my_colors = create_pivoted(Pat3,parcellation_path_Brodmann,8,'.')
# Out:
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 14.09.2018 has nan LEFT stimulation
# 14.09.2018 has nan ROIGHT stimulation
# 17.03.2020 has nan LEFT stimulation
# 17.03.2020 has nan ROIGHT stimulation
# 06.09.2020 has nan LEFT stimulation
# 06.09.2020 has nan ROIGHT stimulation
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation

# %% [markdown]
# ### Store info in dicts

# %%
id_piv_dict = {'Patient1':piv1, 'Patient2':piv2,'Patient3':piv3}
id_global_dict = {'Patient1':pat1_df, 'Patient2':pat2_df,'Patient3':pat3_df}
id_patient_dict =  {'Patient1':Pat1,'Patient2':Pat2, 'Patient3':Pat3}

# %% [markdown]
# ### Get bimodal

# %%
my_df = bimodal_plot_main(Pat3, parcellation_path_Brodmann, 'VTA_04')
bimodal_connectivity(my_df, 'VTA_04', destination_folder='/media/brainstimmaps/DATA/20xx_Projects/2025_DBSinDepression/01_Documents/03_Figures', sorting=True, scaling=False, custom_title='Bimodal connectivity for an example VAT')

# %%
intersubjects_connectivity_summary('MADRS','best', id_piv_dict, id_global_dict, id_patient_dict,parcellation_path_Brodmann,my_colors, '/media/brainstimmaps/DATA/20xx_Projects/2025_DBSinDepression/01_Documents/03_Figures')
# Out:
# for Patient1 the  best VTA for measure  MADRS is at the date 26_05_2020 with % improvement 61.67
# for Patient2 the  best VTA for measure  MADRS is at the date 17_03_2020 with % improvement 18.33
# for Patient3 the  best VTA for measure  MADRS is at the date 22_07_2020 with % improvement 21.66
# 26.05.2020
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 14.09.2018 has nan LEFT stimulation
# 14.09.2018 has nan ROIGHT stimulation
# 17.03.2020
# 17.03.2020 has nan LEFT stimulation
# 17.03.2020 has nan ROIGHT stimulation
# 06.09.2020 has nan LEFT stimulation
# 06.09.2020 has nan ROIGHT stimulation
# 22.07.2020
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation

# %%
intersubjects_connectivity_summary('HAMD','best', id_piv_dict, id_global_dict, id_patient_dict,parcellation_path_Brodmann,my_colors, '/media/brainstimmaps/DATA/20xx_Projects/2025_DBSinDepression/01_Documents/03_Figures')
# Out:
# for Patient1 the  best VTA for measure  HAMD is at the date 17_12_2019 with % improvement 41.54
# for Patient2 the  best VTA for measure  HAMD is at the date 17_03_2020 with % improvement 10.77
# for Patient3 the  best VTA for measure  HAMD is at the date 22_07_2020 with % improvement 9.23
# 17.12.2019
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 14.09.2018 has nan LEFT stimulation
# 14.09.2018 has nan ROIGHT stimulation
# 17.03.2020
# 17.03.2020 has nan LEFT stimulation
# 17.03.2020 has nan ROIGHT stimulation
# 06.09.2020 has nan LEFT stimulation
# 06.09.2020 has nan ROIGHT stimulation
# 22.07.2020
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation

# %%
intersubjects_connectivity_summary('SOFAS','best', id_piv_dict, id_global_dict, id_patient_dict,parcellation_path_Brodmann,my_colors, '/media/brainstimmaps/DATA/20xx_Projects/2025_DBSinDepression/01_Documents/03_Figures')
# Out:
# for Patient1 the  best VTA for measure  SOFAS is at the date 04_07_2019 with % improvement 50.0
# for Patient2 the  best VTA for measure  SOFAS is at the date 17_03_2020 with % improvement 0.0
# for Patient3 the  best VTA for measure  SOFAS is at the date 22_07_2020 with % improvement 25.0
# 04.07.2019
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 14.09.2018 has nan LEFT stimulation
# 14.09.2018 has nan ROIGHT stimulation
# 17.03.2020
# 17.03.2020 has nan LEFT stimulation
# 17.03.2020 has nan ROIGHT stimulation
# 06.09.2020 has nan LEFT stimulation
# 06.09.2020 has nan ROIGHT stimulation
# 22.07.2020
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation

# %%
intersubjects_connectivity_summary('SHAPS','best', id_piv_dict, id_global_dict, id_patient_dict,parcellation_path_Brodmann,my_colors, '/media/brainstimmaps/DATA/20xx_Projects/2025_DBSinDepression/01_Documents/03_Figures')
# Out:
# for Patient1 the  best VTA for measure  SHAPS is at the date 18_01_2019 with % improvement 78.57
# for Patient2 the  best VTA for measure  SHAPS is at the date 17_03_2020 with % improvement 28.57
# for Patient3 the  best VTA for measure  SHAPS is at the date 04_12_2019 with % improvement 7.14
# 18.01.2019
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 14.09.2018 has nan LEFT stimulation
# 14.09.2018 has nan ROIGHT stimulation
# 17.03.2020
# 17.03.2020 has nan LEFT stimulation
# 17.03.2020 has nan ROIGHT stimulation
# 06.09.2020 has nan LEFT stimulation
# 06.09.2020 has nan ROIGHT stimulation
# 04.12.2019
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation

# %%
struct_1 = create_bilateral_df(Pat1, parcellation_path_Brodmann)
struct_2= create_bilateral_df(Pat2, parcellation_path_Brodmann)
struct_3 = create_bilateral_df(Pat3, parcellation_path_Brodmann)
# Out:
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 14.09.2018 has nan LEFT stimulation
# 14.09.2018 has nan ROIGHT stimulation
# 17.03.2020 has nan LEFT stimulation
# 17.03.2020 has nan ROIGHT stimulation
# 06.09.2020 has nan LEFT stimulation
# 06.09.2020 has nan ROIGHT stimulation
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation

# %%
def area_vs_impro(area,patient,brod):
    struct = create_bilateral_df(patient,brod)
    total_weight_day = struct.groupby(['date']).sum().to_dict()['sum_of_weight']
    struct['perc'] = struct.apply(lambda x: (x.sum_of_weight / total_weight_day[x.date]) * 100, axis=1)
    area_df = struct[struct.area == area]
    impro_df = improvement_df(patient.assessment_path+'/perc_impro.mat')
    
    return area_df, impro_df

# %%
scales = ['BDI', 'HAMD', 'MADRS', 'SHAPS', 'Sheehan', 'SOFAS']

# %%
## area 25

# %%
#d_patient_dict =  {'Patient1':Pat1,'Patient2':Pat2, 'Patient3':Pat3}
area_df_all = {pat_ID : area_vs_impro('BA25',val, parcellation_path_Brodmann) for pat_ID,val in id_patient_dict.items()}
# Out:
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 10.09.2018 has nan LEFT stimulation
# 10.09.2018 has nan ROIGHT stimulation
# 14.09.2018 has nan LEFT stimulation
# 14.09.2018 has nan ROIGHT stimulation
# 17.03.2020 has nan LEFT stimulation
# 17.03.2020 has nan ROIGHT stimulation
# 06.09.2020 has nan LEFT stimulation
# 06.09.2020 has nan ROIGHT stimulation
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation
# 20.09.2019 has nan LEFT stimulation
# 20.09.2019 has nan ROIGHT stimulation

# %%
#per subject
for measure in scales :
        plt.figure()
        
        for pat, dfs in area_df_all.items():
            plt.title(measure+':'+pat)
            plt.scatter(dfs[1][measure],dfs[0]['perc'],label=pat)
            plt.ylabel('percentage structural connection area 25')
            plt.xlabel('percentage improvement on scale')
            plt.legend()
            plt.show()

# %%
# all subjects
for measure in scales :
        plt.figure()
        plt.title(measure)
        for pat, dfs in area_df_all.items():
            plt.scatter(dfs[1][measure],dfs[0]['perc'],label=pat)
            plt.xlabel('percentage structural connection area 25')
            plt.ylabel('percentage improvement on scale')
        plt.legend()
        plt.show()

# %%
## area 16

# %%
area_df_all16 = {pat_ID : area_vs_impro('BA16',val, parcellation_path_Brodmann) for pat_ID,val in id_patient_dict.items()}

# %%
#per subject
for measure in scales :
        plt.figure()
        
        for pat, dfs in area_df_all.items():
            plt.title(measure+':'+pat)
            plt.scatter(dfs[1][measure],dfs[0]['perc'],label=pat)
            plt.ylabel('percentage structural connection area 25')
            plt.xlabel('percentage improvement on scale')
            plt.legend()
            plt.show()

# %%
# all subjects
for measure in scales :
        plt.figure()
        plt.title(measure)
        for pat, dfs in area_df_all16.items():
            plt.scatter(dfs[1][measure],dfs[0]['perc'],label=pat)
            plt.ylabel('percentage structural connection area 16')
            plt.xlabel('percentage improvement on scale')
        plt.legend()
        plt.show()
